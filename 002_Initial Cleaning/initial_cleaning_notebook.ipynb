# %%
import pandas as pd
import numpy as np

#display setting
pd.set_option('display.max_colwidth', None)
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 01 Load Data csv

# %%
df_ori1 = pd.read_csv('/Users/ediashtanarendra/Documents/Course 2024/FTDS 036/004_Final Project/p2-final-project-ftds-036-rmt-group-001/001_Data/Raw Data_Paylater and Non Paylater User.csv', sep=";")
df1 = df_ori1.copy()
df1.head()
# Out:
#    Gender  E-Paylater User Status  Educational Background  Year of Birth  \
# 0       2                       1                       3           1997
# 1       1                       2                       1           2002
# 2       1                       1                       1           2002
# 3       2                       2                       3           2002
# 4       1                       2                       3           2002
#
#    Job Status  Monthly Income  \
# 0           2               3
# 1           1               2
# 2           1               2
# 3           1               1
# 4           2               6
#
#    Average monthly expenditure for online shopping in relation to monthly income  \
# 0                                                                              1
# 1                                                                              2
# 2                                                                              1
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 35 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Gender                                                                         810 non-null    int64
#  1   E-Paylater User Status                                                         810 non-null    int64
#  2   Educational Background                                                         810 non-null    int64
#  3   Year of Birth                                                                  810 non-null    int64
#  4   Job Status                                                                     810 non-null    int64
#  5   Monthly Income                                                                 810 non-null    int64
# ...

# %% [markdown]
# # 02 Load Data Excel

# %%
sheet_name = 'Data View'  
df_ori = pd.read_excel('/Users/ediashtanarendra/Documents/Course 2024/FTDS 036/004_Final Project/p2-final-project-ftds-036-rmt-group-001/001_Data/CodebookData_SEMPLS_IBB.xlsx', sheet_name=sheet_name)
df = df_ori.copy()
df.head()
# Out:
#    ID#  Gender       Location  E-Paylater User Status  Educational Background  \
# 0    1       2  West Sumatera                       1                       3
# 1    2       1    DKI Jakarta                       2                       1
# 2    3       1  West Sumatera                       1                       1
# 3    4       2  West Sumatera                       2                       3
# 4    5       1  West Sumatera                       2                       3
#
#    Year of Birth  Job Status  Monthly Income  \
# 0           1997           2               3
# 1           2002           1               2
# 2           2002           1               2
# 3           2002           1               1
# 4           2002           2               6
#
#    Average monthly expenditure for online shopping in relation to monthly income  \
# 0                                                                              1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 37 columns):
#  #   Column                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                          --------------  -----
#  0   ID#                                                                                                                                                             810 non-null    int64
#  1   Gender                                                                                                                                                          810 non-null    int64
# ...

# %% [markdown]
# >perbedaan data csv dan excel yang disediakan dari source data adalah:
# >1. Excel adalah file mentah dari quesioner, penamaan variablenya masih mengukuti poin pertanyaan pada quesioner
# >2. csv adalah file yang telah dirapikan, tidak ada kolom `ID#` dan `Location`

# %% [markdown]
# # 03 Add Agregated Column and Remove Individual Columns

# %%
# List of column groups and their new names
columns_to_group = {
    'impulsive_buying_behaviour': [
        'IBB1: I do most of my online shopping spontaneously.',
        'IBB2: 2.\tI make purchases without planning, and I do not intend to shop when I open the application.',
        'IBB3: 3.\tBefore opening the website or application, I have no desire to shop.',
        'IBB4: 4.\tI cannot resist shopping on the application.'
    ],
    'promotion': [
        'P1: I am interested in shopping online using pay later because of the low/no interest.',
        'P2: I am interested in shopping online using pay later because of shopping discounts when using pay later.',
        'P3: I am interested in shopping online using pay later because of the significant paylater loan limit increase.',
        'P4: I am interested in shopping online using pay later because of direct rewards such as vouchers or items.'
    ],
    'social_influence': [
        'SI1: I am interested in using the e-Paylater credit service because I have seen through social media and mass media that many people already use this service.',
        'SI2:People influence me to use the Paylater credit service app.',
        'SI3: I use the Paylater credit service app because of stories from my friends about Paylater credit.',
        'SI4: Important people to me whose opinions I value, including family, think I should use the Paylater credit service app.',
        'SI5: My environment perceives me more positively because I use the Paylater credit service app.',
        'SI6: In general, my surrounding environment positively influences the Paylater credit service app I use.'
    ],
    'happiness': [
        'H1: Online shopping makes me happy.',
        'H2: Online shopping makes me excited on boring days.',
        'H3: I feel happy when I shop online.',
        'H4: Online shopping makes me feel better.'
    ],
    'self_control': [
        'SC1: I am good at resisting temptation.',
        'SC2: I never let myself lose control.',
        'SC3: I do things that feel good at the moment but regret later.',
        'SC4: Sometimes I can\'t resist doing something, even though I know it\'s wrong.',
        'SC5: I often act without considering all the alternatives.'
    ],
    'normative_evaluation': [
        'NE1: In my opinion, buying products or services impulsively through various online applications is WRONG.',
        'NE2: I view the behavior of buying products or services impulsively through various online applications as IRRATIONAL.',
        'NE3: In my opinion, buying products or services impulsively through various online applications is not a smart choice.',
        'NE4: I can not understand why some people buy products or services impulsively through various online applications.',
        'NE5: In my opinion, buying products or services impulsively through various online applications is very childish.'
    ]
}

# Calculate averages for each group and assign to new columns
for new_col, col_list in columns_to_group.items():
    df[new_col] = df[col_list].mean(axis=1)

# List of original grouped columns to drop
columns_to_drop = [col for group in columns_to_group.values() for col in group]

# Drop the original grouped columns
df = df.drop(columns=columns_to_drop)

# %%
df
# Out:
#      ID#  Gender       Location  E-Paylater User Status  \
# 0      1       2  West Sumatera                       1
# 1      2       1    DKI Jakarta                       2
# 2      3       1  West Sumatera                       1
# 3      4       2  West Sumatera                       2
# 4      5       1  West Sumatera                       2
# ..   ...     ...            ...                     ...
# 805  806       1  West Sumatera                       1
# 806  807       1  West Sumatera                       1
# 807  808       2  West Sumatera                       1
# 808  809       2  West Sumatera                       1
# 809  810       2  West Sumatera                       1
#
#      Educational Background  Year of Birth  Job Status  Monthly Income  \
# 0                         3           1997           2               3
# 1                         1           2002           1               2
# 2                         1           2002           1               2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 15 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   ID#                                                                            810 non-null    int64
#  1   Gender                                                                         810 non-null    int64
#  2   Location                                                                       810 non-null    object
#  3   E-Paylater User Status                                                         810 non-null    int64
#  4   Educational Background                                                         810 non-null    int64
#  5   Year of Birth                                                                  810 non-null    int64
# ...

# %% [markdown]
# >sekarang kita memiliki 14 kolom saja.

# %% [markdown]
# # 04 Decode Demographic Columns Value for EDA Purpose

# %%
#gender
df['Gender'] = df['Gender'].replace({1: 'Male', 2: 'Female'})
#payleter user status
df['E-Paylater User Status'] = df['E-Paylater User Status'].replace({1: 'Non e-paylater user', 2: 'e-paylater user'})
#edu background
df['Educational Background'] = df['Educational Background'].replace({
    1: 'Until Senior High School',
    2: 'Diploma I, II, III',
    3: 'Bachelor/Diploma IV',
    4: 'Post Graduate'
})
#job status
df['Job Status'] = df['Job Status'].replace({
    1: 'Students',
    2: 'Working',
    3: 'Not Working',
    4: 'Entrepreneur'
})
#monthly income
df['Monthly Income'] = df['Monthly Income'].replace({
    1: 'Less than Rp 1,000,000',
    2: 'Rp 1,000,001 - Rp 2,500,000',
    3: 'Rp 2,500,001 - Rp 5,000,000',
    4: 'Rp 5,000,001 - Rp 7,500,000',
    5: 'Rp 7,500,001 - Rp 10,000,000',
    6: 'More than Rp 10,000,000'
})
#avg monthly expenditure percentage
df['Average monthly expenditure for online shopping in relation to monthly income'] = df['Average monthly expenditure for online shopping in relation to monthly income'].replace({
    1: 'Less than 20%',
    2: '21% - 40%',
    3: '41% - 60%',
    4: '61% - 80%',
    5: '81% - 100%',
    6: 'More than 100%'
})

# %%
df
# Out:
#      ID#  Gender       Location E-Paylater User Status  \
# 0      1  Female  West Sumatera    Non e-paylater user
# 1      2    Male    DKI Jakarta        e-paylater user
# 2      3    Male  West Sumatera    Non e-paylater user
# 3      4  Female  West Sumatera        e-paylater user
# 4      5    Male  West Sumatera        e-paylater user
# ..   ...     ...            ...                    ...
# 805  806    Male  West Sumatera    Non e-paylater user
# 806  807    Male  West Sumatera    Non e-paylater user
# 807  808  Female  West Sumatera    Non e-paylater user
# 808  809  Female  West Sumatera    Non e-paylater user
# 809  810  Female  West Sumatera    Non e-paylater user
#
#        Educational Background  Year of Birth    Job Status  \
# 0         Bachelor/Diploma IV           1997       Working
# 1    Until Senior High School           2002      Students
# 2    Until Senior High School           2002      Students
# 3         Bachelor/Diploma IV           2002      Students
# ...

# %% [markdown]
# # 05 Column Re-naming

# %%
df.rename(columns={
    'ID#': 'ID',
    'Average monthly expenditure for online shopping in relation to monthly income': 'Online Shopping Expenditure Percentage',
    'impulsive_buying_behaviour': 'Impulsive Buying Behavior Score',
    'promotion': 'Promotion Score',
    'social_influence': 'Social Influence Score',
    'happiness': 'Happiness Score',
    'self_control': 'Self Control Score',
    'normative_evaluation': 'Normative Evaluation Score'
}, inplace=True)

# %%
df
# Out:
#       ID  Gender       Location E-Paylater User Status  \
# 0      1  Female  West Sumatera    Non e-paylater user
# 1      2    Male    DKI Jakarta        e-paylater user
# 2      3    Male  West Sumatera    Non e-paylater user
# 3      4  Female  West Sumatera        e-paylater user
# 4      5    Male  West Sumatera        e-paylater user
# ..   ...     ...            ...                    ...
# 805  806    Male  West Sumatera    Non e-paylater user
# 806  807    Male  West Sumatera    Non e-paylater user
# 807  808  Female  West Sumatera    Non e-paylater user
# 808  809  Female  West Sumatera    Non e-paylater user
# 809  810  Female  West Sumatera    Non e-paylater user
#
#        Educational Background  Year of Birth    Job Status  \
# 0         Bachelor/Diploma IV           1997       Working
# 1    Until Senior High School           2002      Students
# 2    Until Senior High School           2002      Students
# 3         Bachelor/Diploma IV           2002      Students
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      810 non-null    int64
#  1   Gender                                  810 non-null    object
#  2   Location                                810 non-null    object
#  3   E-Paylater User Status                  810 non-null    object
#  4   Educational Background                  810 non-null    object
#  5   Year of Birth                           810 non-null    int64
#  6   Job Status                              810 non-null    object
#  7   Monthly Income                          810 non-null    object
#  8   Online Shopping Expenditure Percentage  810 non-null    object
#  9   Impulsive Buying Behavior Score         810 non-null    float64
# ...

# %% [markdown]
# # 05 Save to csv

# %%
df.to_csv('initial_cleaning.csv', index=False)

# %% [markdown]
# # 06 Make Rounded Score for impulsive_buying_behaviour,	promotion,	social_influence,	happiness,	self_control,	normative_evaluation

# %%
df_rounded= df.copy()
# List of columns to round
columns_to_round = [
    "Impulsive Buying Behavior Score",
    "Promotion Score",
    "Social Influence Score",
    "Happiness Score",
    "Self Control Score",
    "Normative Evaluation Score"
]

# Apply rounding to the selected columns
df_rounded[columns_to_round] = df_rounded[columns_to_round].applymap(round)
df_rounded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      810 non-null    int64
#  1   Gender                                  810 non-null    object
#  2   Location                                810 non-null    object
#  3   E-Paylater User Status                  810 non-null    object
#  4   Educational Background                  810 non-null    object
#  5   Year of Birth                           810 non-null    int64
#  6   Job Status                              810 non-null    object
#  7   Monthly Income                          810 non-null    object
#  8   Online Shopping Expenditure Percentage  810 non-null    object
#  9   Impulsive Buying Behavior Score         810 non-null    int64
# ...

# %% [markdown]
# # 07 Save DF Rounded to csv

# %%
df_rounded.to_csv('initial_cleaning_rounded.csv', index=False)

# %% [markdown]
# # 08 csv for indivividual variable

# %%
df_individual = df_ori.copy()
df_individual
# Out:
#      ID#  Gender       Location  E-Paylater User Status  \
# 0      1       2  West Sumatera                       1
# 1      2       1    DKI Jakarta                       2
# 2      3       1  West Sumatera                       1
# 3      4       2  West Sumatera                       2
# 4      5       1  West Sumatera                       2
# ..   ...     ...            ...                     ...
# 805  806       1  West Sumatera                       1
# 806  807       1  West Sumatera                       1
# 807  808       2  West Sumatera                       1
# 808  809       2  West Sumatera                       1
# 809  810       2  West Sumatera                       1
#
#      Educational Background  Year of Birth  Job Status  Monthly Income  \
# 0                         3           1997           2               3
# 1                         1           2002           1               2
# 2                         1           2002           1               2
# ...

# %%
#gender
df_individual['Gender'] = df_individual['Gender'].replace({1: 'Male', 2: 'Female'})
#payleter user status
df_individual['E-Paylater User Status'] = df_individual['E-Paylater User Status'].replace({1: 'Non e-paylater user', 2: 'e-paylater user'})
#edu background
df_individual['Educational Background'] = df_individual['Educational Background'].replace({
    1: 'Until Senior High School',
    2: 'Diploma I, II, III',
    3: 'Bachelor/Diploma IV',
    4: 'Post Graduate'
})
#job status
df_individual['Job Status'] = df_individual['Job Status'].replace({
    1: 'Students',
    2: 'Working',
    3: 'Not Working',
    4: 'Entrepreneur'
})
#monthly income
df_individual['Monthly Income'] = df_individual['Monthly Income'].replace({
    1: 'Less than Rp 1,000,000',
    2: 'Rp 1,000,001 - Rp 2,500,000',
    3: 'Rp 2,500,001 - Rp 5,000,000',
    4: 'Rp 5,000,001 - Rp 7,500,000',
    5: 'Rp 7,500,001 - Rp 10,000,000',
    6: 'More than Rp 10,000,000'
})
#avg monthly expenditure percentage
df_individual['Average monthly expenditure for online shopping in relation to monthly income'] = df_individual['Average monthly expenditure for online shopping in relation to monthly income'].replace({
    1: 'Less than 20%',
    2: '21% - 40%',
    3: '41% - 60%',
    4: '61% - 80%',
    5: '81% - 100%',
    6: 'More than 100%'
})

# %%
df_individual.rename(columns={
    'ID#': 'ID',
    'Average monthly expenditure for online shopping in relation to monthly income': 'Online Shopping Expenditure Percentage',
    'impulsive_buying_behaviour': 'Impulsive Buying Behavior Score',
    'promotion': 'Promotion Score',
    'social_influence': 'Social Influence Score',
    'happiness': 'Happiness Score',
    'self_control': 'Self Control Score',
    'normative_evaluation': 'Normative Evaluation Score'
}, inplace=True)

# %%
# Dictionary for renaming columns
rename_columns = {
    'IBB1: I do most of my online shopping spontaneously.': 'IBB1',
    'IBB2: 2.\tI make purchases without planning, and I do not intend to shop when I open the application.': 'IBB2',
    'IBB3: 3.\tBefore opening the website or application, I have no desire to shop.': 'IBB3',
    'IBB4: 4.\tI cannot resist shopping on the application.': 'IBB4',
    'P1: I am interested in shopping online using pay later because of the low/no interest.': 'P1',
    'P2: I am interested in shopping online using pay later because of shopping discounts when using pay later.': 'P2',
    'P3: I am interested in shopping online using pay later because of the significant paylater loan limit increase.': 'P3',
    'P4: I am interested in shopping online using pay later because of direct rewards such as vouchers or items.': 'P4',
    'SI1: I am interested in using the e-Paylater credit service because I have seen through social media and mass media that many people already use this service.': 'SI1',
    'SI2:People influence me to use the Paylater credit service app.': 'SI2',
    'SI3: I use the Paylater credit service app because of stories from my friends about Paylater credit.': 'SI3',
    'SI4: Important people to me whose opinions I value, including family, think I should use the Paylater credit service app.': 'SI4',
    'SI5: My environment perceives me more positively because I use the Paylater credit service app.': 'SI5',
    'SI6: In general, my surrounding environment positively influences the Paylater credit service app I use.': 'SI6',
    'H1: Online shopping makes me happy.': 'H1',
    'H2: Online shopping makes me excited on boring days.': 'H2',
    'H3: I feel happy when I shop online.': 'H3',
    'H4: Online shopping makes me feel better.': 'H4',
    'SC1: I am good at resisting temptation.': 'SC1',
    'SC2: I never let myself lose control.': 'SC2',
    'SC3: I do things that feel good at the moment but regret later.': 'SC3',
    'SC4: Sometimes I can\'t resist doing something, even though I know it\'s wrong.': 'SC4',
    'SC5: I often act without considering all the alternatives.': 'SC5',
    'NE1: In my opinion, buying products or services impulsively through various online applications is WRONG.': 'NE1',
    'NE2: I view the behavior of buying products or services impulsively through various online applications as IRRATIONAL.': 'NE2',
    'NE3: In my opinion, buying products or services impulsively through various online applications is not a smart choice.': 'NE3',
    'NE4: I can not understand why some people buy products or services impulsively through various online applications.': 'NE4',
    'NE5: In my opinion, buying products or services impulsively through various online applications is very childish.': 'NE5'
}

# Renaming columns
df_individual.rename(columns=rename_columns, inplace=True)

# %%
df_individual
# Out:
#       ID  Gender       Location E-Paylater User Status  \
# 0      1  Female  West Sumatera    Non e-paylater user
# 1      2    Male    DKI Jakarta        e-paylater user
# 2      3    Male  West Sumatera    Non e-paylater user
# 3      4  Female  West Sumatera        e-paylater user
# 4      5    Male  West Sumatera        e-paylater user
# ..   ...     ...            ...                    ...
# 805  806    Male  West Sumatera    Non e-paylater user
# 806  807    Male  West Sumatera    Non e-paylater user
# 807  808  Female  West Sumatera    Non e-paylater user
# 808  809  Female  West Sumatera    Non e-paylater user
# 809  810  Female  West Sumatera    Non e-paylater user
#
#        Educational Background  Year of Birth    Job Status  \
# 0         Bachelor/Diploma IV           1997       Working
# 1    Until Senior High School           2002      Students
# 2    Until Senior High School           2002      Students
# 3         Bachelor/Diploma IV           2002      Students
# ...

# %%
df_individual.to_csv('initial_cleaning_individual.csv', index=False)
