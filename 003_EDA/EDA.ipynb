# %% [markdown]
# # Final Project | $SpendWise$
#
# Batch FTDS-RMT-036
#
# Group 001
#
# Team members:
# - Azkia Mudrikah Al Mawaddah as Data Analyst
# - Ediashta Narendra Amarussalam as Data Scientist
# - Muchammad Septyo Al Birqi Purnama as Data Scientist
# - Yocia Meiko Oke as Data Engineer
#
# HuggingFace : [Group1 Deployment](https://huggingface.co/spaces/ymo980/spendwise)
# Original Dataset : [Group1 Dataset](https://data.mendeley.com/datasets/wkjdmrmrg4/4)
# Team GitHub : [Group1 GitHub](https://github.com/FTDS-assignment-bay/p2-final-project-ftds-036-rmt-group-001)

# %% [markdown]
# # i. Background
#
# Paylater merupakan sumber pendapatan tambahan (extended revenue stream) yang berasal dari ekosistem yang telah matang, seperti e-commerce atau layanan ojek online beserta turunannya. Dengan menentukan apakah pelanggan yang sudah ada dalam ekosistem tersebut akan memanfaatkan layanan paylater atau tidak, keuntungan dapat diperoleh tanpa biaya tambahan untuk akuisisi pelanggan (non-profit pada customer acquisition) dan dengan efisiensi biaya pemasaran serta profit pada communication cost.
#
# # ii. Problem statement and objectives
#
# $SpendWise$ bertujuan untuk menentukan apakah existing customer akan menggunakan produk layanan PayLater atau tidak, berdasarkan dengan kondisi demografis serta kebiasaan berbelanja konsumen. Model machine learning akan dibuat menggunakan algoritma KNN, SVM, decision tree, random forest, dan adaptive boosting. Kelima model tersebut akan diuji pada data train dan data test, lalu dibandingkan berdasarkan metrik evaluasi recall dan F1-score. Model dengan nilai recall dan F1-score terbaik akan dipilih untuk disimpan dan digunakan dalam memprediksi data baru. Pemilihan metrik recall bertujuan untuk memastikan model mampu mendeteksi sebanyak mungkin kasus positif yang sebenarnya, sehingga meminimalkan risiko kesalahan dalam klasifikasi data kritis. Sementara itu, F1-score dipilih karena menggabungkan keseimbangan antara presisi dan recall, memastikan model tidak hanya akurat tetapi juga dapat diandalkan dalam mendeteksi risiko secara konsisten.

# %% [markdown]
# # iii. Import Libraries
# Sebelum melakukan load data, dilakukan import libraries terlebih dahulu.
# - pandas digunakan untuk membaca file csv dan untuk membuat dataframe
# - seaborn dan matplotlib digunakan untuk visualisasi data khususnya pada bagian EDA
# - scipy.stats dilakukan untuk melakukan perhitungan statistika

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pointbiserialr

# %% [markdown]
# # iv. Load, Clean, and Manipulating Data
#
# Bagian ini berisi data yang akan dianalisis, normalisasi kolom, dan hal lainnya yang dilakukan sebelum proses EDA.
#
# Data yang digunakan adalah hasil survey mengenai kebiasaan berbelanja online masyarakat. Responden terdiri dari berbagai latar pendidikan, gender, dan usia.

# %%
# load data

df_ = pd.read_csv('initial_cleaning_rounded.csv')
df = df_.copy()
df.head(5)
# Out:
#    ID  Gender       Location E-Paylater User Status    Educational Background  \
# 0   1  Female  West Sumatera    Non e-paylater user       Bachelor/Diploma IV
# 1   2    Male    DKI Jakarta        e-paylater user  Until Senior High School
# 2   3    Male  West Sumatera    Non e-paylater user  Until Senior High School
# 3   4  Female  West Sumatera        e-paylater user       Bachelor/Diploma IV
# 4   5    Male  West Sumatera        e-paylater user       Bachelor/Diploma IV
#
#    Year of Birth Job Status               Monthly Income  \
# 0           1997    Working  Rp 2,500,001 - Rp 5,000,000
# 1           2002   Students  Rp 1,000,001 - Rp 2,500,000
# 2           2002   Students  Rp 1,000,001 - Rp 2,500,000
# 3           2002   Students       Less than Rp 1,000,000
# 4           2002    Working      More than Rp 10,000,000
#
#   Online Shopping Expenditure Percentage  Impulsive Buying Behavior Score  \
# 0                          Less than 20%                                2
# ...

# %%
# memeriksa identitas dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 810 entries, 0 to 809
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      810 non-null    int64
#  1   Gender                                  810 non-null    object
#  2   Location                                810 non-null    object
#  3   E-Paylater User Status                  810 non-null    object
#  4   Educational Background                  810 non-null    object
#  5   Year of Birth                           810 non-null    int64
#  6   Job Status                              810 non-null    object
#  7   Monthly Income                          810 non-null    object
#  8   Online Shopping Expenditure Percentage  810 non-null    object
#  9   Impulsive Buying Behavior Score         810 non-null    int64
# ...

# %% [markdown]
# Rangkuman identitas dataframe di atas menunjukkan data terdiri dari 810 rows tanpa missing value karena jumlah non-null counts untuk seluruh kolom sama dengan jumlah rows data, 8 kolom memliki nilai dengan tipe data integer, dan 7 kolom memliki nilai dengan tipe data object. Sekilas terlihat bahwa monthly income dan online shopping expenditure percentage harusnya memiliki nilai dengan tipe data numeric, namun dalam data ini nilai dari kedua kolom tersebut digolongkan ke dalam beberapa rentang tertentu seperti monthly income less than Rp1.000.000 dan online shopping expenditure percentage 20%-40% sehingga kedua kolom tersebut memiliki nilai dengan tipe data object. Selanjutnya dilakukan pemeriksaan apakah terdapat data yang terduplikasi dalam dataframe ini atau tidak.

# %%
# memeriksa duplikat data

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Hasil pemeriksaan menunjukkan bahwa data tidak memiliki data yang terduplikat. Duplikat data ini harus diperiksa dan di-drop jika ada, untuk menghindari bias pada hasil analisis. Selanjutkan dilakukan normalisasi nama kolom untuk mempermudah proses analisis.

# %%
# normalisasi kolom
df.columns = df.columns.str.replace('[^a-zA-Z0-9]', # menghapus karakter selain huruf
                                    '', # menghapus spasi
                                      regex=True)

# menampilkan 5 data pertama setelah normalisasi kolom
df.head(5)
# Out:
#    ID  Gender       Location  EPaylaterUserStatus     EducationalBackground  \
# 0   1  Female  West Sumatera  Non e-paylater user       Bachelor/Diploma IV
# 1   2    Male    DKI Jakarta      e-paylater user  Until Senior High School
# 2   3    Male  West Sumatera  Non e-paylater user  Until Senior High School
# 3   4  Female  West Sumatera      e-paylater user       Bachelor/Diploma IV
# 4   5    Male  West Sumatera      e-paylater user       Bachelor/Diploma IV
#
#    YearofBirth JobStatus                MonthlyIncome  \
# 0         1997   Working  Rp 2,500,001 - Rp 5,000,000
# 1         2002  Students  Rp 1,000,001 - Rp 2,500,000
# 2         2002  Students  Rp 1,000,001 - Rp 2,500,000
# 3         2002  Students       Less than Rp 1,000,000
# 4         2002   Working      More than Rp 10,000,000
#
#   OnlineShoppingExpenditurePercentage  ImpulsiveBuyingBehaviorScore  \
# 0                       Less than 20%                             2
# ...

# %% [markdown]
# Nama-nama kolom sudah berhasil diubah, selanjutnya dilakukan pemeriksaan untuk masing-masing nilai unik pada setiap kolom. Hal ini bertujuan untuk mempermudah dalam menentukan jenis visualisasi pada analisis.

# %%
# memeriksa banyak nilai unik pada setiap kolom
df.nunique()
# Out:
# ID                                     810
# Gender                                   2
# Location                                23
# EPaylaterUserStatus                      2
# EducationalBackground                    4
# YearofBirth                             40
# JobStatus                                4
# MonthlyIncome                            6
# OnlineShoppingExpenditurePercentage      6
# ImpulsiveBuyingBehaviorScore             5
# PromotionScore                           5
# SocialInfluenceScore                     5
# HappinessScore                           5
# SelfControlScore                         5
# NormativeEvaluationScore                 5
# dtype: int64

# %% [markdown]
# Hasil run code di atas menunjukkan jumlah nilai unik pada masing-masing kolom, terlihat bahwa nilai unik setiap kolom cenderung berada di rentang yang tidak lebih dari 6 dengan 2 kolom yaitu lokasi dan year of birth memiliki jumlah nilai unik yang lebih banyak dari kolom lainnya yaitu 23 dan 40. Selanjutnya dilakukan pemeriksaan deskriptif untuk kolom numerik.

# %%
# analisis deskriptif untuk kolom numerik

df.describe()
# Out:
#                ID  YearofBirth  ImpulsiveBuyingBehaviorScore  PromotionScore  \
# count  810.000000   810.000000                    810.000000      810.000000
# mean   405.500000  1994.111111                      2.769136        2.354321
# std    233.971152    10.020745                      0.952408        1.144293
# min      1.000000  1966.000000                      1.000000        1.000000
# 25%    203.250000  1987.000000                      2.000000        1.000000
# 50%    405.500000  1999.000000                      3.000000        2.000000
# 75%    607.750000  2002.000000                      4.000000        3.000000
# max    810.000000  2005.000000                      5.000000        5.000000
#
#        SocialInfluenceScore  HappinessScore  SelfControlScore  \
# count            810.000000      810.000000        810.000000
# mean               2.339506        3.520988          3.281481
# std                1.021182        0.869866          0.640440
# ...

# %% [markdown]
# Hasil analisis deskriptif di atas menunjukkan bahwa umur responden berada di rentang kelahiran tahun 1966-2005 menunjukkan bahwa penggunaan e-commerce dan bisnis sejenis tersebar ke berbagai generasi. Variasi generasi yang beragam menunjukkan bahwa saat ini e-commerce dan bisnis sejenis mudah diakses tanpa hambatan. Hal ini memungkinkan penggunaan pay later juga dapat menjangkau seluruh generasi, menjadi peluang yang cukup baik bagi pemilik bisnis untuk menawarkan pay later-nya ke seluruh pengguna aplikasi.

# %% [markdown]
# # v. Exploratory Data Analysis
#
# Setelah melakukan data cleaning dan manipulating, selanjutnya kita melakukan Exploratory Data Analysis. Objektif utama dari analisis ini adalah untuk memahami karakteristik digital consumer mengenai perilaku belanja mereka khususnya pada pembelian impulsif secara online menggunakan paylater. Untuk mengetahui hal tersebut kita akan menjawab pertanyaan-pertanyaan di bawah ini:
#
# 1. Bagaimana karakteristik responden survey?
# 2. Bagaimana proporsi gender terhadap impulsive buying behavior?
# 3. Apakah setiap perilaku saling berkorelasi?
# 4. Bagaimana kecenderungan responden dalam setiap perilaku?
# 5. Bagaimana pengaruh keenam variabel pernyataan terhadap keputusan untuk menggunakan pay later?
# 6. Apakah tingkat pendidikan tertentu cenderung mendominasi pengguna PayLater?
# 7. Bagaimana tingkat pengeluaran belanja online terkait dengan pendapatan bulanan?
# 8. Bagaimana distribusi pendapatan bulanan terhadap status penggunaan pay later?
#
# Untuk menjawab pertanyaan di atas, kita lakukan proses-proses berikut

# %% [markdown]
# ## 1. Bagaimana karakteristik responden survey?

# %% [markdown]
# ### a. Karakteristik reponden berdasarkan gender

# %%
gender = df['Gender'].value_counts()

# Membuat pie chart
plt.figure(figsize=(6, 6))
gender.plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'pink'])
plt.title('Distribution of Gender')
plt.ylabel('')  # Menghapus label default
plt.show()

# %% [markdown]
# Responden perempuan lebih banyak daripada responden laki-laki sehingga hasil analisis kemungkinan mencerminkan lebih banyak perilaku perempuan daripada laki-laki. Namun pengambilan insight dari analisis akan tetap berlaku secara general karena berdasarkan sumber [A](https://www.statista.com/statistics/1362970/indonesia-share-of-population-making-online-purchases-by-gender/) dan sumber [B](https://dataindonesia.id/) menyatakan bahwa frekuensi perempuan berbelanja online memang lebih banyak dari laki-laki.

# %%
# Crosstab untuk menghitung distribusi
paylater_vs_gender = pd.crosstab(df['Gender'], df['EPaylaterUserStatus'])
print(paylater_vs_gender)

# Plot bar chart
paylater_vs_gender.plot(kind='bar', figsize=(8, 6), color=['lightcoral', 'darkred'], edgecolor='black')

# Tambahkan judul dan label
plt.title('Distribusi Pengguna PayLater Berdasarkan Gender', fontsize=16)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Jumlah Pengguna', fontsize=12)
plt.legend(title='PayLater User Status')
plt.xticks(rotation=0)
plt.show()
# Out:
# EPaylaterUserStatus  Non e-paylater user  e-paylater user
# Gender
# Female                               417              134
# Male                                 189               70

# %% [markdown]
# ### b. Lokasi responden untuk menggambarkan kondisi demografis

# %%
location = df['Location'].value_counts()

# Membuat bar chart
location.plot(kind='bar', figsize=(15, 5), color='royalblue')
plt.title('Distribusi Lokasi')
plt.xlabel('Lokasi')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  # Memutar label agar lebih terbaca
plt.show()

# %% [markdown]
# Berdasarkan data yang didominasi oleh responden dari Sumatera Barat, generalisasi hasil analisis ke seluruh Indonesia menjadi terbatas. Ketimpangan dalam distribusi geografis responden dapat menghasilkan bias, karena perilaku atau preferensi pengguna E-Paylater di Sumatera Barat mungkin tidak mencerminkan pola yang sama di provinsi lain dengan karakteristik ekonomi, sosial, dan budaya yang berbeda. Oleh karena itu, hasil analisis ini dapat dikembangkan lebih luas dengan melakukan survey dengan responden yang lebih tersebar luar dari seluruh Indonesia. Untuk saat ini, analisis dilakukan sesuai dengan kondisi data sebenarnya dengan generalisasi untuk seluruh Indonesia.

# %% [markdown]
# ### c. Latar belakang pendidikan reponden
#
# Latar pendidikan bisa berpengaruh terhadap pemahaman konsumen terhadap paylater, seperti memahami resiko dan manfaat dalam menggunakan paylater, kontrol diri dalam penggunaan paylater, kemampuan mengelola pendapatan dan pengeluaran, dan lain-lain. Sehingga penting untuk mengetahui latar pendidikan responden dalam analisis ini.

# %%
edu = df['EducationalBackground'].value_counts()

# Membuat pie chart
plt.figure(figsize=(6, 6))
edu.plot.pie(autopct='%1.1f%%', startangle=90, colors=['forestgreen', 'lightgreen', 'yellowgreen', 'lime'])
plt.title('Distribusi Latar Pendidikan Responden')
plt.ylabel('')  # Menghapus label default
plt.show()

# %% [markdown]
# Distribusi latar pendidikan menunjukkan mayoritas responden berpendidikan SMA (40%) dan S1/D4 (34%), sementara sisanya berasal dari S2 (17.3%) dan D1-3 (8.8%). Hal ini menunjukkan bahwa target pengguna layanan E-Paylater sebagian besar adalah individu dengan pendidikan menengah hingga tinggi. Karena pendidikan dapat memengaruhi literasi keuangan dan perilaku konsumsi, penting untuk menganalisis apakah pengguna dengan pendidikan yang lebih tinggi memiliki kecenderungan lebih besar dalam menggunakan layanan PayLater dibandingkan yang berpendidikan SMA. Pemahaman ini dapat membantu merancang strategi pemasaran yang sesuai dengan kebutuhan segmen pendidikan yang dominan dalam data.

# %% [markdown]
# ### d. Persebaran status pekerjaan responden

# %% [markdown]
# Pekerjaan memiliki pengaruh terhadap keputusan keuangan masing-masing responden seperti menentukan kemampuan keuangan, keputusan berbelanja, menyesuaikan produk layanan, dan lain-lain.

# %%
job = df['JobStatus'].value_counts()

# Membuat pie chart
plt.figure(figsize=(6, 6))
job.plot.pie(autopct='%1.1f%%', startangle=90, colors=['plum', 'thistle', 'darkviolet', 'orchid'])
plt.title('Distribusi Pekerjaan Responden')
plt.ylabel('')  # Menghapus label default
plt.show()

# %% [markdown]
# Distribusi status pekerjaan responden menunjukkan bahwa sebagian besar adalah siswa (49.6%) dan pekerja (41.6%), sementara 4.9% memiliki usaha bisnis, dan 3.8% tidak bekerja. Data ini menunjukkan bahwa pengguna layanan E-Paylater berpotensi berasal dari dua segmen utama: pelajar yang mungkin memiliki keterbatasan finansial dan pekerja yang memiliki penghasilan tetap. Perilaku belanja dan kebutuhan keuangan kedua kelompok ini kemungkinan berbeda, sehingga strategi promosi layanan PayLater dapat disesuaikan—misalnya, menawarkan paket promosi khusus pelajar atau manfaat tambahan untuk pekerja. Kelompok kecil seperti pengusaha dan belum bekerja mungkin memerlukan pendekatan lebih spesifik untuk meningkatkan relevansi layanan bagi mereka.

# %% [markdown]
# ### e. Persebaran pendapatan responden

# %% [markdown]
# Mengetahui persebaran pendapatan responden penting untuk memahami kemampuan finansial dan pola belanja mereka. Pendapatan memengaruhi keputusan untuk menggunakan layanan seperti PayLater, sementara mereka dengan pendapatan lebih rendah mungkin melihatnya sebagai alat untuk memenuhi kebutuhan mendesak. Informasi ini membantu untuk merancang promosi atau fitur yang relevan berdasarkan kemampuan finansial pelanggan.

# %%
income = df['MonthlyIncome'].value_counts()

# Membuat bar chart
income.plot(kind='bar', figsize=(15, 5), color='sandybrown')
plt.title('Distribusi Pendapatan Responden')
plt.xlabel('Income')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  # Memutar label agar lebih terbaca
plt.show()

# %% [markdown]
# Distribusi pendapatan responden menunjukkan bahwa mayoritas memiliki pendapatan kurang dari Rp 1,000,000 (297 orang), diikuti oleh kelompok Rp 1,000,001 - Rp 2,500,000 (143 orang) dan Rp 2,500,001 - Rp 5,000,000 (106 orang). Responden dengan pendapatan lebih tinggi, seperti lebih dari Rp 10,000,000 (124 orang), Rp 5,000,001 - Rp 7,500,000 (70 orang), dan Rp 7,500,001 - Rp 10,000,000 (70 orang) lebih sedikit.
#
# Dominasi kelompok berpendapatan rendah mencerminkan potensi target pasar E-Paylater yang kuat di segmen ini, mengingat layanan PayLater dapat menarik konsumen dengan keterbatasan finansial yang membutuhkan solusi pembayaran fleksibel. Namun, keberadaan kelompok berpenghasilan tinggi juga menunjukkan peluang untuk mengembangkan strategi produk premium atau fitur tambahan untuk menarik minat mereka.

# %% [markdown]
# ### f. Distribusi usia responden

# %% [markdown]
# Mengetahui umur responden penting karena usia memengaruhi kebutuhan, preferensi, dan perilaku finansial. Kelompok usia muda (misalnya, Gen Z dan milenial) cenderung lebih akrab dengan teknologi dan lebih impulsif dalam berbelanja, sehingga lebih mungkin menggunakan layanan PayLater. Di sisi lain, kelompok usia yang lebih tua mungkin lebih berhati-hati dalam pengeluaran dan mengutamakan stabilitas finansial.

# %%
birth = df['YearofBirth'].value_counts()

# Membuat bar chart
birth.plot(kind='bar', figsize=(15, 5), color='darkgray')
plt.title('Distribusi usia Responden')
plt.xlabel('Income')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  # Memutar label agar lebih terbaca
plt.show()

# %% [markdown]
# Distribusi tahun lahir responden menunjukkan bahwa mayoritas berasal dari generasi muda, dengan puncak kelahiran pada tahun 2002 (lebih dari 100 responden), diikuti oleh 2003 dan 2001. Semakin jauh tahun kelahiran ke belakang, jumlah responden cenderung menurun, menunjukkan bahwa dataset ini didominasi oleh individu dari generasi Z. Hal ini relevan untuk layanan E-Paylater, karena generasi muda cenderung lebih terbuka terhadap teknologi finansial dan belanja online. Fokus strategi bisnis dapat diarahkan untuk memenuhi preferensi dan kebutuhan generasi muda ini, misalnya melalui promosi berbasis digital atau penawaran fleksibilitas pembayaran.

# %% [markdown]
# ### g. Persentase rata-rata yang dihabiskan untuk belanja online

# %% [markdown]
# Mengetahui persentase rata-rata pendapatan yang dihabiskan untuk belanja online memberikan gambaran tentang kebiasaan konsumsi digital responden. Hal ini membantu mengidentifikasi seberapa besar belanja online menjadi bagian dari pengeluaran mereka. Konsumen dengan persentase tinggi mungkin lebih terbuka terhadap layanan seperti PayLater untuk mendukung kebutuhan belanja mereka.

# %%
expend = df['OnlineShoppingExpenditurePercentage'].value_counts()

# Membuat bar chart
expend.plot(kind='bar', figsize=(15, 5), color='dimgray')
plt.title('Distribusi Pengeluaran Belanja Online')
plt.xlabel('Income')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)  # Memutar label agar lebih terbaca
plt.show()

# %% [markdown]
# Distribusi pengeluaran online menunjukkan bahwa mayoritas responden (lebih dari 500 orang) menghabiskan kurang dari 20% dari pendapatan mereka untuk belanja online, diikuti oleh kelompok 21% - 40% dengan jumlah sekitar 200 responden. Kelompok dengan pengeluaran yang lebih tinggi, seperti 41% - 60%, 61% - 80%, hingga lebih dari 100%, jauh lebih sedikit. Pola ini menunjukkan bahwa sebagian besar pengguna cenderung berbelanja secara hemat, sehingga layanan E-Paylater dapat menarik perhatian mereka dengan menawarkan fleksibilitas pembayaran yang dapat meningkatkan daya beli tanpa harus membebani pengeluaran bulanan mereka. Strategi pemasaran juga dapat difokuskan untuk memaksimalkan potensi kelompok dengan pengeluaran lebih rendah ini.

# %% [markdown]
# ## 2. Bagaimana proporsi gender terhadap impulsive buying behavior?

# %%
pd.crosstab(df['Gender'], df['ImpulsiveBuyingBehaviorScore'], normalize='index') * 100
# Out:
# ImpulsiveBuyingBehaviorScore         1          2          3          4  \
# Gender
# Female                        6.352087  37.205082  28.312160  27.404719
# Male                          8.880309  37.451737  26.640927  26.254826
#
# ImpulsiveBuyingBehaviorScore         5
# Gender
# Female                        0.725953
# Male                          0.772201

# %% [markdown]
# Baik pria maupun wanita cenderung memiliki skor Impulsive Buying Behavior yang didominasi oleh nilai 2 dan 3, dengan proporsi terbesar berada pada nilai 2 (sekitar 37%). Skor 5 (sangat setuju) memiliki proporsi yang sangat rendah (<1%) untuk kedua gender. Hal ini menunjukkan bahwa sebagian besar responden, terlepas dari gender, memiliki tingkat perilaku impulsif yang moderat hingga rendah.

# %% [markdown]
# ## 3. Apakah setiap perilaku saling berkorelasi?

# %%
correlation_matrix = df[['ImpulsiveBuyingBehaviorScore', 'PromotionScore', 
                         'SocialInfluenceScore', 'HappinessScore', 
                         'SelfControlScore', 'NormativeEvaluationScore']].corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Korelasi antar perilaku')
plt.show()

# %% [markdown]
# Hasil visualisasi di atas menunjukkan:
# - PromotionScore dan SocialInfluenceScore memiliki korelasi tinggi (0.72), menunjukkan bahwa promosi cenderung memengaruhi persepsi sosial.
# - ImpulsiveBuyingBehaviorScore memiliki korelasi positif dengan SocialInfluenceScore (0.44) dan PromotionScore (0.37), artinya promosi dan pengaruh sosial dapat meningkatkan perilaku pembelian impulsif.
# - SelfControlScore berkorelasi negatif dengan ImpulsiveBuyingBehaviorScore (-0.36), menunjukkan bahwa semakin tinggi pengendalian diri, semakin rendah perilaku pembelian impulsif.
# - Korelasi lainnya relatif lemah, menunjukkan hubungan yang tidak signifikan.

# %% [markdown]
# ## 4. Bagaimana kecenderungan responden dalam setiap perilaku?

# %%
columns = ['ImpulsiveBuyingBehaviorScore', 'PromotionScore', 
          'SocialInfluenceScore', 'HappinessScore', 
          'SelfControlScore', 'NormativeEvaluationScore']

summary = pd.DataFrame({
    col: df[col].value_counts().sort_index() for col in columns
}).fillna(0).astype(int)

summary
# Out:
#    ImpulsiveBuyingBehaviorScore  PromotionScore  SocialInfluenceScore  \
# 1                            58             236                   188
# 2                           302             247                   294
# 3                           225             136                   201
# 4                           219             186                   119
# 5                             6               5                     8
#
#    HappinessScore  SelfControlScore  NormativeEvaluationScore
# 1              20                 2                        17
# 2              90                49                        99
# 3             203               507                       315
# 4             442               223                       276
# 5              55                29                       103

# %% [markdown]
# output di atas menunjukkan bahwa:
#
# - **ImpulsiveBuyingBehaviorScore**: Sebagian besar responden memiliki skor **2** (302 responden) atau **3** (225 responden), menunjukkan kecenderungan perilaku impulsif yang moderat.
# - **PromotionScore** dan **SocialInfluenceScore**: Banyak responden cenderung memberikan skor **2** atau **3**, menunjukkan pengaruh promosi dan sosial yang sedang.
# - **HappinessScore**: Skor **4** (442 responden) mendominasi, menunjukkan tingkat kebahagiaan yang tinggi pada mayoritas responden.
# - **SelfControlScore**: Mayoritas responden memberikan skor **3** (507 responden), menunjukkan kontrol diri yang moderat.
# - **NormativeEvaluationScore**: Responden cenderung memberikan skor **3** (315 responden) dan **4** (276 responden), mencerminkan evaluasi norma yang cukup tinggi.
#
# Responden umumnya menunjukkan sikap moderat hingga positif pada sebagian besar perilaku yang diukur.

# %% [markdown]
# ## 5. Bagaimana pengaruh keenam variabel pernyataan terhadap keputusan untuk menggunakan pay later?

# %%
# encode kolom EPaylaterUserStatus
df['EPaylaterUserStatus_Encoded'] = df['EPaylaterUserStatus'].map({'Non e-paylater user': 0, 'e-paylater user': 1})
df.head(5)
# Out:
#    ID  Gender       Location  EPaylaterUserStatus     EducationalBackground  \
# 0   1  Female  West Sumatera  Non e-paylater user       Bachelor/Diploma IV
# 1   2    Male    DKI Jakarta      e-paylater user  Until Senior High School
# 2   3    Male  West Sumatera  Non e-paylater user  Until Senior High School
# 3   4  Female  West Sumatera      e-paylater user       Bachelor/Diploma IV
# 4   5    Male  West Sumatera      e-paylater user       Bachelor/Diploma IV
#
#    YearofBirth JobStatus                MonthlyIncome  \
# 0         1997   Working  Rp 2,500,001 - Rp 5,000,000
# 1         2002  Students  Rp 1,000,001 - Rp 2,500,000
# 2         2002  Students  Rp 1,000,001 - Rp 2,500,000
# 3         2002  Students       Less than Rp 1,000,000
# 4         2002   Working      More than Rp 10,000,000
#
#   OnlineShoppingExpenditurePercentage  ImpulsiveBuyingBehaviorScore  \
# 0                       Less than 20%                             2
# ...

# %%
# Daftar skor numerik
scores = ['ImpulsiveBuyingBehaviorScore', 'PromotionScore', 'SocialInfluenceScore', 
          'HappinessScore', 'SelfControlScore', 'NormativeEvaluationScore']

results = []

# Hitung korelasi point-biserial untuk setiap skor
for score in scores:
    correlation, p_value = pointbiserialr(df['EPaylaterUserStatus_Encoded'], df[score])
    # Interpretasi
    if p_value < 0.05:
        interpretation = 'Significant'
    else:
        interpretation = 'Not Significant'
    # Tambahkan hasil ke list
    results.append({
        'Score': score,
        'Correlation': correlation,
        'P-Value': p_value,
        'Interpretation': interpretation
    })

# Buat DataFrame dari hasil
results_df = pd.DataFrame(results)

# Tampilkan DataFrame
results_df
# Out:
#                           Score  Correlation       P-Value   Interpretation
# 0  ImpulsiveBuyingBehaviorScore     0.188537  6.439764e-08      Significant
# 1                PromotionScore     0.454425  1.603657e-42      Significant
# 2          SocialInfluenceScore     0.378289  5.893310e-29      Significant
# 3                HappinessScore     0.048154  1.709514e-01  Not Significant
# 4              SelfControlScore    -0.144073  3.862857e-05      Significant
# 5      NormativeEvaluationScore    -0.048474  1.681205e-01  Not Significant

# %% [markdown]
# Hasil korelasi keenam variabel terhadap kolom
#
# 1. **ImpulsiveBuyingBehaviorScore** memiliki korelasi positif sebesar 0,188 dan nilai p yang sangat kecil (p-value ≈ 6,44e-08), menunjukkan hubungan yang signifikan. Ini berarti semakin tinggi kecenderungan perilaku pembelian impulsif, semakin tinggi kemungkinan seseorang menjadi pengguna PayLater. Hubungan ini meskipun lemah, cukup jelas secara statistik.
#
# 2. **PromotionScore** menunjukkan korelasi yang cukup kuat sebesar 0,454 dan sangat signifikan (p-value ≈ 1,60e-42). Ini mengindikasikan bahwa pengguna PayLater lebih responsif terhadap promosi, yang berpotensi menjadi salah satu faktor pendorong utama dalam mengadopsi layanan ini.
#
# 3. **SocialInfluenceScore** memiliki korelasi positif sebesar 0,378 dan juga signifikan (p-value ≈ 5,89e-29). Ini menunjukkan bahwa faktor pengaruh sosial cukup berperan dalam keputusan pengguna untuk menggunakan PayLater, yang mengindikasikan pentingnya peran komunitas atau rekomendasi sosial.
#
# 4. **HappinessScore** menunjukkan korelasi yang sangat kecil sebesar 0,048 dan tidak signifikan (p-value ≈ 0,171). Ini menunjukkan bahwa tingkat kebahagiaan tidak berhubungan dengan keputusan untuk menggunakan layanan PayLater.
#
# 5. **SelfControlScore** menunjukkan korelasi negatif sebesar -0,144 dan signifikan (p-value ≈ 3,86e-05). Ini mengindikasikan bahwa semakin tinggi tingkat pengendalian diri, semakin kecil kemungkinan seseorang menggunakan layanan PayLater, mungkin karena preferensi untuk menghindari hutang atau pengeluaran tidak terkendali.
#
# 6. **NormativeEvaluationScore** memiliki korelasi negatif yang sangat kecil (-0,048) dan tidak signifikan (p-value ≈ 0,168), menunjukkan bahwa evaluasi normatif individu tidak memiliki pengaruh yang cukup berarti terhadap keputusan untuk menggunakan PayLater.

# %% [markdown]
# ## 6. Apakah tingkat pendidikan tertentu cenderung mendominasi pengguna PayLater?

# %%
education_paylater = pd.crosstab(df['EducationalBackground'], df['EPaylaterUserStatus'])

# Plot bar chart
education_paylater.plot(kind='bar', figsize=(8, 6), color=['skyblue', 'salmon'], edgecolor='black')
plt.title('Pengguna PayLater Berdasarkan Tingkat Pendidikan', fontsize=16)
plt.xlabel('Educational Background', fontsize=12)
plt.ylabel('Jumlah Responden', fontsize=12)
plt.legend(title='PayLater User Status', labels=['No', 'Yes'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Sebagian besar responden dengan latar belakang pendidikan hingga SMA dan Sarjana/Diploma IV cenderung tidak menggunakan layanan PayLater, sedangkan pengguna dari tingkat pendidikan ini lebih sedikit jumlahnya. Hal ini menunjukkan bahwa adopsi PayLater di kalangan tertentu masih cukup rendah. Namun, peluang untuk meningkatkan penggunaan bisa diperoleh dengan pendekatan edukasi yang sesuai, terutama bagi kelompok dengan pendidikan hingga SMA yang tampak memiliki potensi lebih besar. Dengan memahami pola ini, strategi promosi dapat difokuskan pada mengurangi hambatan dalam penggunaan PayLater di segmen ini, seperti meningkatkan literasi keuangan dan manfaat layanan yang ditawarkan.

# %% [markdown]
# ## 7. Bagaimana tingkat pengeluaran belanja online terkait dengan pendapatan bulanan?

# %%
heatmap_data = pd.crosstab(df['MonthlyIncome'], df['OnlineShoppingExpenditurePercentage'])
plt.figure(figsize=(10, 5))
sns.heatmap(heatmap_data, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Hubungan Pendapatan Bulanan dan Persentase Pengeluaran Berbelanja Online')
plt.ylabel('Pendapatan Bulanan')
plt.xlabel('Persentase Pengeluaran Belanja Online')
plt.tight_layout()
plt.show()

# %% [markdown]
# Sebagian besar responden dengan pendapatan bulanan di bawah Rp 1 juta memiliki pengeluaran online kurang dari 20%, menjadikan segmen ini paling dominan dalam kategori rendah pengeluaran. Secara bertahap, jumlah pengeluaran yang lebih tinggi tampak menurun meskipun terdapat beberapa kelompok di rentang pendapatan lainnya yang menunjukkan pola serupa, seperti mereka dengan penghasilan lebih dari Rp 10 juta. Tren ini mengisyaratkan bahwa meskipun ada variasi pendapatan, preferensi untuk pengeluaran yang lebih kecil masih cukup umum. Hasil ini bisa digunakan untuk merancang strategi pemasaran yang sesuai dengan pola belanja kelompok yang lebih hemat, menawarkan fleksibilitas dan insentif yang mendorong penggunaan layanan online tanpa membebani pengeluaran.

# %% [markdown]
# ## 8. Bagaimana distribusi pendapatan bulanan terhadap status penggunaan pay later?

# %%
# Buat tabel distribusi pendapatan berdasarkan status
income_distribution = pd.crosstab(df['MonthlyIncome'], df['EPaylaterUserStatus'], normalize='columns') * 100

# Visualisasi menggunakan bar plot
income_distribution.plot(kind='bar', figsize=(10, 6), colormap='viridis')
plt.title('Distribusi Pendapatan Bulanan Berdasarkan Status Pengguna PayLater')
plt.ylabel('Persentase (%)')
plt.xlabel('Pendapatan Bulanan')
plt.legend(title='Status PayLater', labels=['Non-User', 'User'], bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Hasil visualisasi di atas menunjukkan bahwa:
#
# - Pengguna **PayLater** lebih banyak berasal dari kelompok dengan pendapatan **Rp 5.000.001 - Rp 7.500.000** dan **Rp 7.500.001 - Rp 10.000.000**, menunjukkan kecenderungan bahwa pengguna PayLater lebih banyak di kelompok pendapatan menengah ke atas.
# - Non-pengguna **PayLater** didominasi oleh kelompok pendapatan **di bawah Rp 1.000.000**, menunjukkan bahwa kelompok ini mungkin kurang tertarik atau kurang memenuhi syarat untuk menggunakan layanan PayLater.
# - Terdapat pola bahwa semakin tinggi pendapatan, semakin besar persentase pengguna layanan **PayLater** dibandingkan non-pengguna.
#
# Distribusi ini menunjukkan bahwa tingkat pendapatan bulanan memengaruhi keputusan atau kemungkinan seseorang menggunakan layanan **PayLater**.

# %% [markdown]
# # vi. Kesimpulan
#
# Berdasarkan analisis, beberapa temuan penting dapat dijadikan dasar pengambilan keputusan bisnis untuk pengembangan layanan E-Paylater:
#
# 1. **Perilaku Impulsif dan Kontrol Diri:**
# Sebagian besar responden menunjukkan tingkat perilaku impulsif yang moderat hingga rendah (dominan pada skor 2 dan 3) dengan skor impulsif yang lebih tinggi dipengaruhi oleh promosi (**r = 0.37**) dan pengaruh sosial (**r = 0.44**). Sebaliknya, pengendalian diri berkorelasi negatif dengan perilaku impulsif (**r = -0.36**). Hal ini menegaskan pentingnya memanfaatkan promosi dan pengaruh sosial untuk memicu pembelian, tetapi tetap mempertimbangkan keseimbangan agar tidak menurunkan pengalaman pengguna dengan perilaku belanja yang terlalu impulsif.
#
# 2. **Korelasi Antar Faktor:**
# Promosi (**PromotionScore**) dan pengaruh sosial (**SocialInfluenceScore**) memiliki korelasi kuat (**r = 0.72**), menunjukkan bahwa strategi promosi yang efektif dapat memperkuat persepsi sosial. Selain itu, korelasi positif keduanya dengan perilaku impulsif mempertegas potensi peningkatan transaksi melalui pendekatan promosi yang dipersonalisasi.
#
# 3. **Distribusi Kebahagiaan dan Evaluasi Norma:**
# Mayoritas responden menunjukkan tingkat kebahagiaan tinggi (dominan pada skor 4, sebanyak 442 responden) dan evaluasi norma yang cukup positif (skor 3 dan 4 dominan). Tingkat kebahagiaan yang tinggi dapat dimanfaatkan untuk meningkatkan loyalitas terhadap layanan, sedangkan evaluasi norma yang positif mencerminkan penerimaan sosial terhadap layanan PayLater.
#
# 4. **Segmentasi Pendapatan:**
# Pengguna PayLater cenderung berasal dari kelompok pendapatan menengah ke atas (Rp 5.000.001 - Rp 7.500.000 dan Rp 7.500.001 - Rp 10.000.000). Sebaliknya, kelompok dengan pendapatan di bawah Rp 1.000.000 lebih banyak terdiri dari non-pengguna, menunjukkan kemungkinan kendala keuangan atau kurangnya minat di segmen ini. Pola ini menunjukkan bahwa tingkat pendapatan memengaruhi keputusan untuk menggunakan PayLater, sehingga strategi pemasaran dapat difokuskan pada segmen berpendapatan menengah ke atas sambil mengembangkan pendekatan yang lebih inklusif untuk kelompok berpendapatan rendah.
#
# 5. **Insight Tambahan dari Perilaku dan Persepsi:**
# Responden umumnya memiliki kontrol diri yang moderat (skor dominan 3), perilaku promosi yang sedang (skor 2 atau 3 dominan), dan pengaruh sosial yang tidak terlalu besar. Strategi perlu menyesuaikan pendekatan agar layanan PayLater mampu meningkatkan persepsi nilai di segmen dengan kontrol diri tinggi, tanpa mengurangi potensi pembelian impulsif yang sehat.
